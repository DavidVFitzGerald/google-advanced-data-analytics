# %% [markdown]
# # Automatidata project
# **Course 3 - The Power of Statistics**

# %% [markdown]
# You are a data professional in a data consulting firm, called Automatidata. The current project for their newest client, the New York City Taxi & Limousine Commission (New York City TLC) is reaching its midpoint, having completed a project proposal, Python coding work, and exploratory data analysis.
#
# You receive a new email from Uli King, Automatidata’s project manager. Uli tells your team about a new request from the New York City TLC: to analyze the relationship between fare amount and payment type. A follow-up email from Luana includes your specific assignment: to conduct an A/B test.
#
# A notebook was structured and prepared to help you in this project. Please complete the following questions.

# %% [markdown]
# # Course 3 End-of-course project: Statistical analysis
#
# In this activity, you will practice using statistics to analyze and interpret data. The activity covers fundamental concepts such as descriptive statistics and hypothesis testing. You will explore the data provided and conduct A/B and hypothesis testing.
# <br/>
#
# **The purpose** of this project is to demonstrate knowledge of how to prepare, create, and analyze A/B tests. Your A/B test results should aim to find ways to generate more revenue for taxi cab drivers.
#
# **Note:** For the purpose of this exercise, assume that the sample data comes from an experiment in which customers are randomly selected and divided into two groups: 1) customers who are required to pay with credit card, 2) customers who are required to pay with cash. Without this assumption, we cannot draw causal conclusions about how payment method affects fare amount.
#
# **The goal** is to apply descriptive statistics and hypothesis testing in Python. The goal for this A/B test is to sample data and analyze whether there is a relationship between payment type and fare amount. For example: discover if customers who use credit cards pay higher fare amounts than customers who use cash.
#
# *This activity has four parts:*
#
# **Part 1:** Imports and data loading
# * What data packages will be necessary for hypothesis testing?
#
# **Part 2:** Conduct EDA and hypothesis testing
# * How did computing descriptive statistics help you analyze your data?
#
# * How did you formulate your null hypothesis and alternative hypothesis?
#
# **Part 3:** Communicate insights with stakeholders
#
# * What key business insight(s) emerged from your A/B test?
#
# * What business recommendations do you propose based on your results?
#
# <br/>
# Follow the instructions and answer the questions below to complete the activity. Then, you will complete an Executive Summary using the questions listed on the PACE Strategy Document.
#
# Be sure to complete this activity before moving on. The next course item will provide you with a completed exemplar to compare to your own work.

# %% [markdown]
# # **Conduct an A/B test**

# %% [markdown]
# <img src="images/Pace.png" width="100" height="100" align=left>
#
# # **PACE stages**

# %% [markdown]
# Throughout these project notebooks, you'll see references to the problem-solving framework PACE. The following notebook components are labeled with the respective PACE stage: Plan, Analyze, Construct, and Execute.

# %% [markdown]
# <img src="images/Plan.png" width="100" height="100" align=left>
#
#
# ## PACE: Plan
#
# In this stage, consider the following questions where applicable to complete your code response:
# 1. What is your research question for this data project? Later on, you will need to formulate the null and alternative hypotheses as the first step of your hypothesis test. Consider your research question now, at the start of this task.

# %% [markdown]
# Is there a relationship between the payment type and fare amount for taxi rides in New York City?

# %% [markdown]
# *Complete the following steps to perform statistical analysis of your data:*

# %% [markdown]
# ### Task 1. Imports and data loading

# %% [markdown]
# Import packages and libraries needed to compute descriptive statistics and conduct a hypothesis test.

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint: </strong></h4></summary>
#
# Before you begin, recall the following Python packages and functions that may be useful:
#
# *Main functions*: stats.ttest_ind(a, b, equal_var)
#
# *Other functions*: mean()
#
# *Packages*: pandas, stats.scipy
#
# </details>

# %%
import numpy as np
import pandas as pd
from scipy import stats

# %% [markdown]
# **Note:** As shown in this cell, the dataset has been automatically loaded in for you. You do not need to download the .csv file, or provide more code, in order to access the dataset and proceed with this lab. Please continue with this activity by completing the following instructions.

# %%
# Load dataset into dataframe
taxi_data = pd.read_csv("2017_Yellow_Taxi_Trip_Data.csv", index_col = 0)

# %% [markdown]
# <img src="images/Analyze.png" width="100" height="100" align=left>
#
# <img src="images/Construct.png" width="100" height="100" align=left>
#
# ## PACE: **Analyze and Construct**
#
# In this stage, consider the following questions where applicable to complete your code response:
# 1. Data professionals use descriptive statistics for Exploratory Data Analysis. How can computing descriptive statistics help you learn more about your data in this stage of your analysis?

# %% [markdown]
# Descriptive statistics provide an overview of the data that makes it possible to quickly understand the distribution of the data.

# %% [markdown]
# ### Task 2. Data exploration
#
# Use descriptive statistics to conduct Exploratory Data Analysis (EDA).

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint: </strong></h4></summary>
#
# Refer back to *Self Review Descriptive Statistics* for this step-by-step proccess.
#
# </details>

# %% [markdown]
# **Note:** In the dataset, `payment_type` is encoded in integers:
# *   1: Credit card
# *   2: Cash
# *   3: No charge
# *   4: Dispute
# *   5: Unknown

# %%
taxi_data.shape
# Out:
# (22699, 17)

# %%
taxi_data.head(5)
# Out:
#            VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 24870114          2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 35634249          1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 38942136          2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 30841670          2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
#
#            passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 24870114                 6           3.34           1                  N
# 35634249                 1           1.80           1                  N
# 106203690                1           1.00           1                  N
# 38942136                 1           3.70           1                  N
# 30841670                 1           4.37           1                  N
#
#            PULocationID  DOLocationID  payment_type  fare_amount  extra  \
# ...

# %%
taxi_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22699 entries, 24870114 to 17208911
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               22699 non-null  int64
#  1   tpep_pickup_datetime   22699 non-null  object
#  2   tpep_dropoff_datetime  22699 non-null  object
#  3   passenger_count        22699 non-null  int64
#  4   trip_distance          22699 non-null  float64
#  5   RatecodeID             22699 non-null  int64
#  6   store_and_fwd_flag     22699 non-null  object
#  7   PULocationID           22699 non-null  int64
#  8   DOLocationID           22699 non-null  int64
#  9   payment_type           22699 non-null  int64
#  10  fare_amount            22699 non-null  float64
#  11  extra                  22699 non-null  float64
#  12  mta_tax                22699 non-null  float64
#  13  tip_amount             22699 non-null  float64
# ...

# %%
taxi_data.describe(include="all")
# Out:
#             VendorID   tpep_pickup_datetime  tpep_dropoff_datetime  \
# count   22699.000000                  22699                  22699
# unique           NaN                  22687                  22688
# top              NaN  07/03/2017 3:45:19 PM  10/18/2017 8:07:45 PM
# freq             NaN                      2                      2
# mean        1.556236                    NaN                    NaN
# std         0.496838                    NaN                    NaN
# min         1.000000                    NaN                    NaN
# 25%         1.000000                    NaN                    NaN
# 50%         2.000000                    NaN                    NaN
# 75%         2.000000                    NaN                    NaN
# max         2.000000                    NaN                    NaN
#
#         passenger_count  trip_distance    RatecodeID store_and_fwd_flag  \
# count      22699.000000   22699.000000  22699.000000              22699
# ...

# %%
taxi_data["payment_type"].value_counts()
# Out:
# 1    15265
# 2     7267
# 3      121
# 4       46
# Name: payment_type, dtype: int64

# %% [markdown]
# You are interested in the relationship between payment type and the fare amount the customer pays. One approach is to look at the average fare amount for each payment type.

# %%
taxi_data.groupby("payment_type")["fare_amount"].mean()
# Out:
# payment_type
# 1    13.429748
# 2    12.213546
# 3    12.186116
# 4     9.913043
# Name: fare_amount, dtype: float64

# %%
import seaborn as sns

# %%
sns.boxplot(x=taxi_data["payment_type"],y=taxi_data["fare_amount"])

# %%
fare_amount_mean = taxi_data["fare_amount"].mean()
fare_amount_std = taxi_data["fare_amount"].std()
lower_limit = fare_amount_mean - 3*fare_amount_std
upper_limit = fare_amount_mean + 3*fare_amount_std
taxi_data_filtered = taxi_data[taxi_data["payment_type"].isin((1,2))]
taxi_data_filtered = taxi_data_filtered[(taxi_data_filtered["fare_amount"] > lower_limit) & (taxi_data_filtered["fare_amount"] < upper_limit)]
taxi_data_filtered["payment_type"] = taxi_data_filtered["payment_type"].map(
    {1: "Credit card", 2: "Cash"}
)
sns.boxplot(x=taxi_data_filtered["payment_type"], y=taxi_data_filtered["fare_amount"])

# %% [markdown]
# Based on the averages shown, it appears that customers who pay in credit card tend to pay a larger fare amount than customers who pay in cash. However, this difference might arise from random sampling, rather than being a true difference in fare amount. To assess whether the difference is statistically significant, you conduct a hypothesis test.

# %% [markdown]
# ### Task 3. Hypothesis testing
#
# Before you conduct your hypothesis test, consider the following questions where applicable to complete your code response:
#
# 1. Recall the difference between the null hypothesis and the alternative hypotheses. Consider your hypotheses for this project as listed below.
#
# $H_0$: There is no difference in the average fare amount between customers who use credit cards and customers who use cash.
#
# $H_A$: There is a difference in the average fare amount between customers who use credit cards and customers who use cash.

# %% [markdown]
# Your goal in this step is to conduct a two-sample t-test. Recall the steps for conducting a hypothesis test:
#
#
# 1.   State the null hypothesis and the alternative hypothesis
# 2.   Choose a signficance level
# 3.   Find the p-value
# 4.   Reject or fail to reject the null hypothesis

# %% [markdown]
# **Note:** For the purpose of this exercise, your hypothesis test is the main component of your A/B test.

# %% [markdown]
# You choose 5% as the significance level and proceed with a two-sample t-test.

# %%
significance_level = 0.05

# %%
cc_data = taxi_data[taxi_data["payment_type"] == 1]
cash_data = taxi_data[taxi_data["payment_type"] == 2]

# %%
print(cc_data["fare_amount"].std())
print(cash_data["fare_amount"].std())
# Out:
# 13.848963537365913
# 11.689940154427685

# %%
tstat, pvalue = stats.ttest_ind(a=cc_data["fare_amount"], b=cash_data["fare_amount"], equal_var=False)
print(f"Statistic value = {tstat}")
print(f"p-value = {pvalue}")
print(f"p-value is smaller than the significance level of {significance_level:.2%}: {pvalue < significance_level}")
# Out:
# Statistic value = 6.866800855655372
# p-value = 6.797387473030518e-12
# p-value is smaller than the significance level of 5.00%: True

# %% [markdown]
# As the p-value is smaller than the significance level, we can reject the null hypothesis. This means that there is a statistically significant difference in the mean fare amount depending on whether a credit card or cash is used, with a significance level of 5%.

# %% [markdown]
# <img src="images/Execute.png" width="100" height="100" align=left>
#
# ## PACE: **Execute**
#
# Consider the questions in your PACE Strategy Document to reflect on the Execute stage.

# %% [markdown]
# ### Task 4. Communicate insights with stakeholders

# %% [markdown]
# *Ask yourself the following questions:*
#
# 1. What business insight(s) can you draw from the result of your hypothesis test?
# 2. Consider why this A/B test project might not be realistic, and what assumptions had to be made for this educational project.

# %% [markdown]
# 1. There is a relationship between payment type and fare amount. Fare amounts paid with a credit card are on average higher than fare amounts paid with cash. Whether there is a causality between the two is unknown.
# 2. We had to assume that the riders were randomly selected, and one group was instructed to pay with cash, while the other group was instructed to pay by credit card, when this is in fact not the case.
#
#     Additionally, there might be a causal relationship between fare amount and payment type: high fares are likely to be more often paid by credit card than with cash, simply because riders might not carry much cash on them.

# %% [markdown]
# **Congratulations!** You've completed this lab. However, you may not notice a green check mark next to this item on Coursera's platform. Please continue your progress regardless of the check mark. Just click on the "save" icon at the top of this notebook to ensure your work has been logged.
